# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

book = np.array([40,43,45,60,67,78])

pd.Series(book)
# Out:
# 0    40
# 1    43
# 2    45
# 3    60
# 4    67
# 5    78
# dtype: int32

# %%
#dictionary method

my_list = {"Name": "Paul", "age": 37, "salary": 120000}, {"Name": "Vickky", "age": 30, "salary": 100000}

pd.DataFrame(my_list, index=[1,2])
# Out:
#      Name  age  salary
# 1    Paul   37  120000
# 2  Vickky   30  100000

# %%
vaccine = pd.read_csv('nigeria-total-population-vs-vaccinated.csv')
vaccine
# Out:
#            Region         State Total population  \
# 0      South East          Abia        3,727,347
# 1      North East       Adamawa        4,248,436
# 2     South South     Akwa Ibom        5,482,177
# 3      South East       Anambra        5,527,809
# 4      North East        Bauchi        6,537,314
# 5     South South       Bayelsa        2,277,961
# 6   North Central         Benue        5,741,815
# 7      North East         Borno        5,860,183
# 8     South South  Cross Rivets        3,866,269
# 9     South South           &&&        3,866,269
# 10    South South         Delta        5,663,362
# 11     South East        Ebonyi        2,880,383
# 12    South South           Edo        4,235,595
# 13     South West         Ekiti        3,270,798
# 14     South West          XXXX          230,900
# 15     South East         Enugu        4,411,119
# 16  North Central           FCT        3,564,126
# 17     North East         Gombe        3,256,962
# ...

# %%
vaccine.dtypes
# Out:
# Region                                 object
# State                                  object
# Total population                       object
# Total Doses Administered (Astra)       object
# Total Doses Administered (Moderna)     object
# Total Doses Administered              float64
# dtype: object

# %%
#extracting a column from a dataframe
vaccine["Total Doses Administered (Astra)"]
# Out:
# 0      61,152
# 1      70,521
# 2      67,760
# 3      62,171
# 4      98,409
# 5      31,800
# 6     107,094
# 7      64,623
# 8      99,813
# 9         NaN
# 10     88,631
# 11     46,696
# 12     76,360
# 13    108,118
# 14     47,000
# 15     69,626
# 16    254,088
# 17     92,502
# 18        145
# 19     63,326
# 20     80,145
# 21    180,598
# 22    184,448
# 23    110,522
# 24     62,558
# 25     45,537
# 26      78-00
# 27    115,042
# 28    669,996
# 29     81,416
# 30     95,799
# 31    191,969
# 32    100,249
# 33    100,684
# 34    169,523
# 35    103,275
# 36    121,889
# 37         43
# 38     52,648
# 39     60,613
# 40     49,079
# 41     68,517
# 42        NaN
# 43        NaN
# 44        NaN
# Name: Total Doses Administered (Astra), dtype: object

# %%
#renaming a column in a dataframe

vaccine.rename(columns={"Total Doses Administered (Astra)":"Astra Doses"}, inplace=True)

# %%
vaccine
# Out:
#            Region         State Total population Astra Doses  \
# 0      South East          Abia        3,727,347      61,152
# 1      North East       Adamawa        4,248,436      70,521
# 2     South South     Akwa Ibom        5,482,177      67,760
# 3      South East       Anambra        5,527,809      62,171
# 4      North East        Bauchi        6,537,314      98,409
# 5     South South       Bayelsa        2,277,961      31,800
# 6   North Central         Benue        5,741,815     107,094
# 7      North East         Borno        5,860,183      64,623
# 8     South South  Cross Rivets        3,866,269      99,813
# 9     South South           &&&        3,866,269         NaN
# 10    South South         Delta        5,663,362      88,631
# 11     South East        Ebonyi        2,880,383      46,696
# 12    South South           Edo        4,235,595      76,360
# 13     South West         Ekiti        3,270,798     108,118
# ...

# %%
vaccine.rename(columns={"Total Doses Administered (Moderna)":"Moderna Doses"}, inplace=True)

# %%
vaccine
# Out:
#            Region         State Total population Astra Doses Moderna Doses  \
# 0      South East          Abia        3,727,347      61,152         25172
# 1      North East       Adamawa        4,248,436      70,521         36302
# 2     South South     Akwa Ibom        5,482,177      67,760         27174
# 3      South East       Anambra        5,527,809      62,171         13874
# 4      North East        Bauchi        6,537,314      98,409         43162
# 5     South South       Bayelsa        2,277,961      31,800          9296
# 6   North Central         Benue        5,741,815     107,094         60256
# 7      North East         Borno        5,860,183      64,623         31878
# 8     South South  Cross Rivets        3,866,269      99,813         51562
# 9     South South           &&&        3,866,269         NaN         51562
# 10    South South         Delta        5,663,362      88,631         24234
# ...

# %%
vaccine.drop([9])
# Out:
#            Region         State Total population Astra Doses Moderna Doses  \
# 0      South East          Abia        3,727,347      61,152         25172
# 1      North East       Adamawa        4,248,436      70,521         36302
# 2     South South     Akwa Ibom        5,482,177      67,760         27174
# 3      South East       Anambra        5,527,809      62,171         13874
# 4      North East        Bauchi        6,537,314      98,409         43162
# 5     South South       Bayelsa        2,277,961      31,800          9296
# 6   North Central         Benue        5,741,815     107,094         60256
# 7      North East         Borno        5,860,183      64,623         31878
# 8     South South  Cross Rivets        3,866,269      99,813         51562
# 10    South South         Delta        5,663,362      88,631         24234
# 11     South East        Ebonyi        2,880,383      46,696         18564
# ...

# %%
vaccine.drop([9,14,18,37], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [117], in <cell line: 1>()
# ----> 1 vaccine.drop([9,14,18,37], inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
vaccine

# %%
vaccine.reindex()
# Out:
#            Region        State Total population Astra Doses Moderna Doses  \
# 0      South East         Abia        3,727,347      61,152         25172
# 1      North East      Adamawa        4,248,436      70,521         36302
# 2     South South    Akwa Ibom        5,482,177      67,760         27174
# 3      South East      Anambra        5,527,809      62,171         13874
# 4      North East       Bauchi        6,537,314      98,409         43162
# 5     South South      Bayelsa        2,277,961      31,800          9296
# 6   North Central        Benue        5,741,815     107,094         60256
# 7      North East        Borno        5,860,183      64,623         31878
# 8     South South  Cross River        3,866,269      99,813         51562
# 10    South South        Delta        5,663,362      88,631         24234
# 11     South East       Ebonyi        2,880,383      46,696         18564
# 12    South South          Edo        4,235,595      76,360         59780
# ...

# %%
vaccine.iloc[8,1] = "Cross River"

# %%
vaccine
# Out:
#            Region        State Total population Astra Doses Moderna Doses  \
# 0      South East         Abia        3,727,347      61,152         25172
# 1      North East      Adamawa        4,248,436      70,521         36302
# 2     South South    Akwa Ibom        5,482,177      67,760         27174
# 3      South East      Anambra        5,527,809      62,171         13874
# 4      North East       Bauchi        6,537,314      98,409         43162
# 5     South South      Bayelsa        2,277,961      31,800          9296
# 6   North Central        Benue        5,741,815     107,094         60256
# 7      North East        Borno        5,860,183      64,623         31878
# 8     South South  Cross River        3,866,269      99,813         51562
# 10    South South        Delta        5,663,362      88,631         24234
# 11     South East       Ebonyi        2,880,383      46,696         18564
# 12    South South          Edo        4,235,595      76,360         59780
# ...

# %%
vaccine
# Out:
#            Region        State Total population Astra Doses Moderna Doses  \
# 0      South East         Abia        3,727,347      61,152         25172
# 1      North East      Adamawa        4,248,436      70,521         36302
# 2     South South    Akwa Ibom        5,482,177      67,760         27174
# 3      South East      Anambra        5,527,809      62,171         13874
# 4      North East       Bauchi        6,537,314      98,409         43162
# 5     South South      Bayelsa        2,277,961      31,800          9296
# 6   North Central        Benue        5,741,815     107,094         60256
# 7      North East        Borno        5,860,183      64,623         31878
# 8     South South  Cross River        3,866,269      99,813         51562
# 10    South South        Delta        5,663,362      88,631         24234
# 11     South East       Ebonyi        2,880,383      46,696         18564
# 12    South South          Edo        4,235,595      76,360         59780
# ...

# %%
vaccine["Total population"].str.replace("," , "").astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [121], in <cell line: 1>()
# ----> 1 vaccine["Total population"].str.replace("," , "").astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
vaccine["Total population"] = vaccine["Total population"].str.replace("," , "").astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [122], in <cell line: 1>()
# ----> 1 vaccine["Total population"] = vaccine["Total population"].str.replace("," , "").astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
vaccine
# Out:
#            Region        State Total population Astra Doses Moderna Doses  \
# 0      South East         Abia        3,727,347      61,152         25172
# 1      North East      Adamawa        4,248,436      70,521         36302
# 2     South South    Akwa Ibom        5,482,177      67,760         27174
# 3      South East      Anambra        5,527,809      62,171         13874
# 4      North East       Bauchi        6,537,314      98,409         43162
# 5     South South      Bayelsa        2,277,961      31,800          9296
# 6   North Central        Benue        5,741,815     107,094         60256
# 7      North East        Borno        5,860,183      64,623         31878
# 8     South South  Cross River        3,866,269      99,813         51562
# 10    South South        Delta        5,663,362      88,631         24234
# 11     South East       Ebonyi        2,880,383      46,696         18564
# 12    South South          Edo        4,235,595      76,360         59780
# ...

# %%
vaccine.dtypes
# Out:
# Region                       object
# State                        object
# Total population             object
# Astra Doses                  object
# Moderna Doses                object
# Total Doses Administered    float64
# dtype: object

# %%
vaccine.drop([26], inplace=True)

# %%
vaccine["Astra Doses"] = vaccine["Astra Doses"].str.replace("," , "").astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [106], in <cell line: 1>()
# ----> 1 vaccine["Astra Doses"] = vaccine["Astra Doses"].str.replace("," , "").astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
vaccine

# %%
vaccine["Total population"].sum(axis=0)

# %%
vaccine.sum(axis=0)

# %%
vaccine.dtypes

# %%
vaccine["Moderna Doses"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [107], in <cell line: 1>()
# ----> 1 vaccine["Moderna Doses"].astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
vaccine["Moderna Doses"] = vaccine["Moderna Doses"].astype(int)

# %%
vaccine

# %%
vaccine.iloc[0:,3:5].sum(axis=1)
# Out:
# 0       61,15225172
# 1       70,52136302
# 2       67,76027174
# 3       62,17113874
# 4       98,40943162
# 5        31,8009296
# 6      107,09460256
# 7       64,62331878
# 8       99,81351562
# 10      88,63124234
# 11      46,69618564
# 12      76,36059780
# 13     108,11847418
# 15       69,6269604
# 16     254,08834846
# 17      92,50217402
# 19      63,32615582
# 20      80,14544254
# 21     180,59843512
# 22     184,44867760
# 23     110,52245906
# 24      62,55830590
# 25      45,53716044
# 27     115,04244954
# 28    669,996236222
# 29      81,41640096
# 30      95,79946114
# 31     191,96981816
# 32     100,24974060
# 33     100,68452934
# 34     169,52374970
# 35     103,27527986
# 36     121,88946158
# 38      52,64818004
# 39      60,61327034
# 40      49,07922778
# 41      68,51732494
# 42                0
# 43                0
# 44                0
# dtype: object

# %%
#sum the astra and moderna doses
vaccine["Total Doses Administered"] = vaccine.iloc[0:,3:5].sum(axis=1)

# %%
vaccine
# Out:
#            Region        State Total population Astra Doses Moderna Doses  \
# 0      South East         Abia        3,727,347      61,152         25172
# 1      North East      Adamawa        4,248,436      70,521         36302
# 2     South South    Akwa Ibom        5,482,177      67,760         27174
# 3      South East      Anambra        5,527,809      62,171         13874
# 4      North East       Bauchi        6,537,314      98,409         43162
# 5     South South      Bayelsa        2,277,961      31,800          9296
# 6   North Central        Benue        5,741,815     107,094         60256
# 7      North East        Borno        5,860,183      64,623         31878
# 8     South South  Cross River        3,866,269      99,813         51562
# 10    South South        Delta        5,663,362      88,631         24234
# 11     South East       Ebonyi        2,880,383      46,696         18564
# 12    South South          Edo        4,235,595      76,360         59780
# ...

# %%
#inserting a column to a specific position
len(vaccine.index)
# Out:
# 40

# %%
numbers = np.arange(1,38)
vaccine.insert(0, "S/N", numbers)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [112], in <cell line: 2>()
#       1 numbers = np.arange(1,38)
# ----> 2 vaccine.insert(0, "S/N", numbers)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4444, in DataFrame.insert(self, loc, column, value, allow_duplicates)
#    4441 if not isinstance(loc, int):
#    4442     raise TypeError("loc must be int")
# -> 4444 value = self._sanitize_column(value)
#    4445 self._mgr.insert(loc, column, value)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4535, in DataFrame._sanitize_column(self, value)
#    4532     return _reindex_for_setitem(value, self.index)
#    4534 if is_list_like(value):
# -> 4535     com.require_length_match(value, self.index)
#    4536 return sanitize_array(value, self.index, copy=True, allow_2d=True)
#
# ...

# %%
vaccine
# Out:
#            Region        State Total population Astra Doses Moderna Doses  \
# 0      South East         Abia        3,727,347      61,152         25172
# 1      North East      Adamawa        4,248,436      70,521         36302
# 2     South South    Akwa Ibom        5,482,177      67,760         27174
# 3      South East      Anambra        5,527,809      62,171         13874
# 4      North East       Bauchi        6,537,314      98,409         43162
# 5     South South      Bayelsa        2,277,961      31,800          9296
# 6   North Central        Benue        5,741,815     107,094         60256
# 7      North East        Borno        5,860,183      64,623         31878
# 8     South South  Cross River        3,866,269      99,813         51562
# 10    South South        Delta        5,663,362      88,631         24234
# 11     South East       Ebonyi        2,880,383      46,696         18564
# 12    South South          Edo        4,235,595      76,360         59780
# ...

# %%
vaccine.sort_values("Region", ascending=True)
# Out:
#            Region        State Total population Astra Doses Moderna Doses  \
# 30  North Central        Niger        5,556,247      95,799         46114
# 16  North Central          FCT        3,564,126     254,088         34846
# 25  North Central         Kogi        4,473,490      45,537         16044
# 27  North Central        Kwara        3,192,893     115,042         44954
# 35  North Central      Plateau        4,200,442     103,275         27986
# 6   North Central        Benue        5,741,815     107,094         60256
# 29  North Central    Nassarawa        2,523,395      81,416         40096
# 17     North East        Gombe        3,256,962      92,502         17402
# 40     North East         Yobe        3,294,137      49,079         22778
# 7      North East        Borno        5,860,183      64,623         31878
# 4      North East       Bauchi        6,537,314      98,409         43162
# 39     North East       Taraba        3,066,834      60,613         27034
# ...

# %%
vaccine.sort_values("State", ascending=False)
# Out:
#            Region        State Total population Astra Doses Moderna Doses  \
# 41     North West      Zamfara        4,515,427      68,517         32494
# 40     North East         Yobe        3,294,137      49,079         22778
# 39     North East       Taraba        3,066,834      60,613         27034
# 38     North West       Sokoto        4,998,090      52,648         18004
# 36    South South       Rivers        7,303,924     121,889         46158
# 35  North Central      Plateau        4,200,442     103,275         27986
# 34     South West          Oyo        7,840,864     169,523         74970
# 33     South West         Osun        4,705,589     100,684         52934
# 32     South West         Ondo        4,671,695     100,249         74060
# 31     South West         Ogun        5,217,716     191,969         81816
# 30  North Central        Niger        5,556,247      95,799         46114
# 29  North Central    Nassarawa        2,523,395      81,416         40096
# ...

# %%
vaccine.groupby(["Region"]).count()
# Out:
#                State  Total population  Astra Doses  Moderna Doses  \
# Region
# North Central      7                 7            7              7
# North East         6                 6            6              6
# North West         7                 7            7              7
# South East         5                 5            5              5
# South South        6                 6            6              6
# South West         6                 6            6              6
#
#                Total Doses Administered
# Region
# North Central                         7
# North East                            6
# North West                            7
# South East                            5
# South South                           6
# South West                            6

# %%
vaccine["Region"].value_counts()

# %%
vaccine.groupby(["Region"]).sum()

# %%
# Out:
#            Region        State Total population Astra Doses Moderna Doses  \
# 0      South East         Abia        3,727,347      61,152         25172
# 1      North East      Adamawa        4,248,436      70,521         36302
# 2     South South    Akwa Ibom        5,482,177      67,760         27174
# 3      South East      Anambra        5,527,809      62,171         13874
# 4      North East       Bauchi        6,537,314      98,409         43162
# 5     South South      Bayelsa        2,277,961      31,800          9296
# 6   North Central        Benue        5,741,815     107,094         60256
# 7      North East        Borno        5,860,183      64,623         31878
# 8     South South  Cross River        3,866,269      99,813         51562
# 10    South South        Delta        5,663,362      88,631         24234
# 11     South East       Ebonyi        2,880,383      46,696         18564
# 12    South South          Edo        4,235,595      76,360         59780
# ...

# %%
vaccine
# Out:
#            Region        State Total population Astra Doses Moderna Doses  \
# 0      South East         Abia        3,727,347      61,152         25172
# 1      North East      Adamawa        4,248,436      70,521         36302
# 2     South South    Akwa Ibom        5,482,177      67,760         27174
# 3      South East      Anambra        5,527,809      62,171         13874
# 4      North East       Bauchi        6,537,314      98,409         43162
# 5     South South      Bayelsa        2,277,961      31,800          9296
# 6   North Central        Benue        5,741,815     107,094         60256
# 7      North East        Borno        5,860,183      64,623         31878
# 8     South South  Cross River        3,866,269      99,813         51562
# 10    South South        Delta        5,663,362      88,631         24234
# 11     South East       Ebonyi        2,880,383      46,696         18564
# 12    South South          Edo        4,235,595      76,360         59780
# ...

# %%
vaccine["Total population"].str.replace(",", "").astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [124], in <cell line: 1>()
# ----> 1 vaccine["Total population"].str.replace(",", "").astype(int)
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5912, in NDFrame.astype(self, dtype, copy, errors)
#    5905     results = [
#    5906         self.iloc[:, i].astype(dtype, copy=copy)
#    5907         for i in range(len(self.columns))
#    5908     ]
#    5910 else:
#    5911     # else, only a single dtype is given
# -> 5912     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913     return self._constructor(new_data).__finalize__(self, method="astype")
#    5915 # GH 33113: handle empty frame or series
#
# File ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py:419, in BaseBlockManager.astype(self, dtype, copy, errors)
# ...

# %%
vaccine.dropna(inplace=True)

# %%
vaccine["Total population"].str.replace(",", "").astype(int)
# Out:
# 0      3727347
# 1      4248436
# 2      5482177
# 3      5527809
# 4      6537314
# 5      2277961
# 6      5741815
# 7      5860183
# 8      3866269
# 10     5663362
# 11     2880383
# 12     4235595
# 13     3270798
# 15     4411119
# 16     3564126
# 17     3256962
# 19     5408756
# 20     5828163
# 21     8252366
# 22    15076892
# 23     7831319
# 24     4440050
# 25     4473490
# 27     3192893
# 28    12000598
# 29     2523395
# 30     5556247
# 31     5217716
# 32     4671695
# 33     4705589
# 34     7840864
# 35     4200442
# 36     7303924
# 38     4998090
# 39     3066834
# 40     3294137
# 41     4515427
# Name: Total population, dtype: int32

# %%
vaccine["Total population"] = vaccine["Total population"].str.replace(",", "").astype(int)

# %%
vaccine
# Out:
#            Region        State  Total population Astra Doses Moderna Doses  \
# 0      South East         Abia           3727347      61,152         25172
# 1      North East      Adamawa           4248436      70,521         36302
# 2     South South    Akwa Ibom           5482177      67,760         27174
# 3      South East      Anambra           5527809      62,171         13874
# 4      North East       Bauchi           6537314      98,409         43162
# 5     South South      Bayelsa           2277961      31,800          9296
# 6   North Central        Benue           5741815     107,094         60256
# 7      North East        Borno           5860183      64,623         31878
# 8     South South  Cross River           3866269      99,813         51562
# 10    South South        Delta           5663362      88,631         24234
# 11     South East       Ebonyi           2880383      46,696         18564
# ...

# %%
vaccine["Astra Doses"] = vaccine["Astra Doses"].str.replace(",", "").astype(int)

# %%
vaccine
# Out:
#            Region        State  Total population  Astra Doses Moderna Doses  \
# 0      South East         Abia           3727347        61152         25172
# 1      North East      Adamawa           4248436        70521         36302
# 2     South South    Akwa Ibom           5482177        67760         27174
# 3      South East      Anambra           5527809        62171         13874
# 4      North East       Bauchi           6537314        98409         43162
# 5     South South      Bayelsa           2277961        31800          9296
# 6   North Central        Benue           5741815       107094         60256
# 7      North East        Borno           5860183        64623         31878
# 8     South South  Cross River           3866269        99813         51562
# 10    South South        Delta           5663362        88631         24234
# 11     South East       Ebonyi           2880383        46696         18564
# ...

# %%
vaccine["Moderna Doses"].astype(int)
# Out:
# 0      25172
# 1      36302
# 2      27174
# 3      13874
# 4      43162
# 5       9296
# 6      60256
# 7      31878
# 8      51562
# 10     24234
# 11     18564
# 12     59780
# 13     47418
# 15      9604
# 16     34846
# 17     17402
# 19     15582
# 20     44254
# 21     43512
# 22     67760
# 23     45906
# 24     30590
# 25     16044
# 27     44954
# 28    236222
# 29     40096
# 30     46114
# 31     81816
# 32     74060
# 33     52934
# 34     74970
# 35     27986
# 36     46158
# 38     18004
# 39     27034
# 40     22778
# 41     32494
# Name: Moderna Doses, dtype: int32

# %%
vaccine["Moderna Doses"]  = vaccine["Moderna Doses"].astype(int)

# %%
vaccine
# Out:
#            Region        State  Total population  Astra Doses  Moderna Doses  \
# 0      South East         Abia           3727347        61152          25172
# 1      North East      Adamawa           4248436        70521          36302
# 2     South South    Akwa Ibom           5482177        67760          27174
# 3      South East      Anambra           5527809        62171          13874
# 4      North East       Bauchi           6537314        98409          43162
# 5     South South      Bayelsa           2277961        31800           9296
# 6   North Central        Benue           5741815       107094          60256
# 7      North East        Borno           5860183        64623          31878
# 8     South South  Cross River           3866269        99813          51562
# 10    South South        Delta           5663362        88631          24234
# 11     South East       Ebonyi           2880383        46696          18564
# ...

# %%
vaccine.iloc[0:, 3:5].sum(axis=1)
# Out:
# 0      86324
# 1     106823
# 2      94934
# 3      76045
# 4     141571
# 5      41096
# 6     167350
# 7      96501
# 8     151375
# 10    112865
# 11     65260
# 12    136140
# 13    155536
# 15     79230
# 16    288934
# 17    109904
# 19     78908
# 20    124399
# 21    224110
# 22    252208
# 23    156428
# 24     93148
# 25     61581
# 27    159996
# 28    906218
# 29    121512
# 30    141913
# 31    273785
# 32    174309
# 33    153618
# 34    244493
# 35    131261
# 36    168047
# 38     70652
# 39     87647
# 40     71857
# 41    101011
# dtype: int64

# %%
vaccine["Total Doses Administered"] = vaccine.iloc[0:, 3:5].sum(axis=1)

# %%
vaccine
# Out:
#            Region        State  Total population  Astra Doses  Moderna Doses  \
# 0      South East         Abia           3727347        61152          25172
# 1      North East      Adamawa           4248436        70521          36302
# 2     South South    Akwa Ibom           5482177        67760          27174
# 3      South East      Anambra           5527809        62171          13874
# 4      North East       Bauchi           6537314        98409          43162
# 5     South South      Bayelsa           2277961        31800           9296
# 6   North Central        Benue           5741815       107094          60256
# 7      North East        Borno           5860183        64623          31878
# 8     South South  Cross River           3866269        99813          51562
# 10    South South        Delta           5663362        88631          24234
# 11     South East       Ebonyi           2880383        46696          18564
# ...

# %%
import seaborn
plt.style.use('seaborn')
vaccine.plot(kind="line", title="Region  and covid vaccine", x="Region", y="Total Doses Administered", figsize=(15,10), marker="o", color="red")
# Out:
# <AxesSubplot:title={'center':'Region  and covid vaccine'}, xlabel='Region'>

# %%
plt.style.use('seaborn')
vaccine.plot(kind="bar", title="Region  and covid vaccine", x="Region", y="Total Doses Administered", figsize=(15,10), color="orange")
# Out:
# <AxesSubplot:title={'center':'Region  and covid vaccine'}, xlabel='Region'>

# %%
plt.style.use('seaborn')
total = vaccine.sort_values("Total Doses Administered", ascending=True)
total.plot(kind="barh", title="Region  and covid vaccine", x="Region", y="Total Doses Administered", figsize=(15,10), color="brown")
# Out:
# <AxesSubplot:title={'center':'Region  and covid vaccine'}, ylabel='Region'>

# %%
all_south_west = vaccine.loc[vaccine["Region"]=="South West"]
# Out:
#         Region  State  Total population  Astra Doses  Moderna Doses  \
# 13  South West  Ekiti           3270798       108118          47418
# 28  South West  Lagos          12000598       669996         236222
# 31  South West   Ogun           5217716       191969          81816
# 32  South West   Ondo           4671695       100249          74060
# 33  South West   Osun           4705589       100684          52934
# 34  South West    Oyo           7840864       169523          74970
#
#     Total Doses Administered
# 13                    155536
# 28                    906218
# 31                    273785
# 32                    174309
# 33                    153618
# 34                    244493
